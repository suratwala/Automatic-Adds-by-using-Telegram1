# %%
from tkinter import *
from PIL import ImageTk,Image
from tkinter import messagebox
import ast
import webbrowser

# %%
telegram1 = Tk()
telegram1.title('telegram login page')

telegram1.geometry('950x500+300+500')
telegram1.configure(bg='#fff')
telegram1.resizable(False,False)

def signin():
    username=usr.get()
    password=password1.get()
    
    d= "https://web.telegram.org/z/"
    webbrowser.open(d)
          


load = Image.open("E:\\Telegram-message\\telegram_sign_up_image.jpg")
render = ImageTk.PhotoImage(load)

img = Label(telegram1, image=render,border=0,bg='white')
img.image = render
img.place(x=50, y=50)

#Label(telegram1,image=render,bg ="white").place(x=50,y=50)


    

frame = Frame(telegram1, width=350,height=350,bg="white")
frame.place(x=480,y=70)

heading=Label(frame, text ='sign in', fg='#57a1f8', bg ='white', font=('Telegram UI Light', 23,'bold'))
heading.place(x=100,y=5)

########################################################################

def on_enter(e):
    usr.delete(0, 'end')
    
def on_leave(e):
    name=usr.get()
    if name=='':
        usr.insert(0, 'Name')
    
    

usr=Entry(frame, width=25, fg='black', border=0, bg ='white', font=('Telegram UI Light', 11))
usr.place(x=30,y=80)
usr.insert(0,'Name')
usr.bind('<FocusIn>', on_enter)
usr.bind('<FocusOut>', on_leave)

Frame(frame, width=295,height=3,bg="black").place(x=25,y=107)

########################################################################

def on_enter(e):
    password1.delete(0, 'end')
    
def on_leave(e):
    name=password1.get()
    if name=='':
        password1.insert(0, 'Surname')

password1=Entry(frame, width=25, fg='black', border=0, bg ='white', font=('Telegram UI Light', 11))
password1.place(x=30,y=150)
password1.insert(0,'Surname')
password1.bind('<FocusIn>', on_enter)
password1.bind('<FocusOut>', on_leave)

Frame(frame, width=295,height=3,bg="black").place(x=25,y=177)

################################################################################


Button(frame, width=39,pady=8,text='sign in',bg="#57a1f8",fg='white',border=0).place(x=35,y=204)
label=Label(frame,bg="white",fg='black',font=('Telegram UI Light', 9))
label.place(x=75,y=270)
            

telegram1.mainloop()

# %% [markdown]
# # sign in and sign up page

# %%
from tkinter import *
from PIL import ImageTk,Image
from tkinter import messagebox
import ast

# %%
telegram1 = Tk()
telegram1.title('telegram login page')

telegram1.geometry('950x500+300+500')
telegram1.configure(bg='#fff')
telegram1.resizable(False,False)


def signin():
    username=usr.get()
    password=password1.get()
    
    file=open('datasheet.txt','r')
    d=file.read()
    r=ast.literal_eval(d)
    file.close()
    
    #print(r.keys())
    #print(r.values())
    
    if username in r.keys() and password==r[username]:
        screen=Toplevel(telegram1)
        screen.title("App")
        #screen.geometry('300*200')
        screen.config(bg="red")
        #messagebox.showinfo("showinfo", "Information")
        #messagebox.showinfo(title="Login Success", message="You successfully logged in.")
        #Label(screen,text='Hello Everyone!',bg='#fff',font=('calibri(Body)',50,'bold')).pack(expand=True)
        label1=Label(screen,text='Hello Everyone!',bg="white",fg='black',font=('calibri(Body)',50,'bold'))
        label1.place(x=75,y=270)
        
        screen.mainloop()
    
    else:
        messagebox.showerror("Invalid","Invalid username or password")
        
def signup_command():
    telegram2=Toplevel(telegram1)
    telegram2.title('telegram login page')
    telegram2.geometry('950x500+300+500')
    telegram2.configure(bg='#fff')
    telegram2.resizable(False,False)
    
    def signup():
        username1=user1.get()
        password3=password2.get()
        conform_password=conform_code.get()
        if password3==conform_password:
            try:
                file=open('datasheet.txt','r+')
                d=file.read()
                r=ast.literal_eval(d)
                
                dict2={username1:password3}
                r.update(dict2)
                file.truncate(0)
                file.close()
            
                file=open('datasheet.txt','w')
                w=file.write(str(r))
            
                messagebox.showinfo('signup','successfully sign up')
                telegram2.destroy()
                
                
            except:
                file=open('datasheet.txt','w')
                pp=str({username1:password3})
                file.write(pp)
                file.close()
        else:
            messagebox.showerror('Invalid',"Both password should match")
            
    def sign():
        telegram2.destroy()

    
    load = Image.open("E:\\Telegram-message\\botfathr.png")
    render1 = ImageTk.PhotoImage(load)

    img1 = Label(telegram2, image=render1)
    img1.image = render1
    img1.place(x=50, y=90)

    frame1=Frame(telegram2,width=350,height=390,bg='#fff')
    frame1.place(x=480,y=50)
    
    heading2=Label(frame1,width=25,fg='black',border=0,bg='white',font=('Telegram UI Light', 23, 'bold'))
    heading2.place(x=100,y=5)


########################################################
    def on_enter(e):
        user1.delete(0, 'end')
    def on_leave(e):
        name1=user1.get()
        if name1=='':
            user1.insert(0, 'username')
    user1=Entry(frame1, width=25, fg='black', border=0, bg ='white', font=('Telegram UI Light', 11))
    user1.place(x=30,y=80)
    user1.insert(0,'username')
    user1.bind('<FocusIn>', on_enter)
    user1.bind('<FocusOut>', on_leave)
    Frame(frame1, width=295,height=3,bg="black").place(x=25,y=107)
    
########################################################################
    def on_enter(e):
        password2.delete(0, 'end')
    def on_leave(e):
        name1=password2.get()
        if name1=='':
            password2.insert(0, 'password')
    password2=Entry(frame1, width=25, fg='black', border=0, bg ='white', font=('Telegram UI Light', 11))
    password2.place(x=30,y=150)
    password2.insert(0,'password')
    password2.bind('<FocusIn>', on_enter)
    password2.bind('<FocusOut>', on_leave)
    Frame(frame1, width=295,height=3,bg="black").place(x=25,y=177)
    
################################################################################
    
    def on_enter(e):
        conform_code.delete(0, 'end')
    
    def on_leave(e):
        name1=conform_code.get()
        if name1=='':
            conform_code.insert(0, 'conform password')
    
    conform_code=Entry(frame1, width=25, fg='black', border=0, bg ='white', font=('Telegram UI Light', 11))
    conform_code.place(x=30,y=220)
    conform_code.insert(0,'conform password')
    conform_code.bind('<FocusIn>', on_enter)
    conform_code.bind('<FocusOut>', on_leave)
    Frame(frame1, width=295,height=2,bg="black").place(x=25,y=247)
    
########################################################################
    
    Button(frame1, width=39,pady=7,text='sign up',bg="#57a1f8",fg='white',border=0,command=signup).place(x=35,y=280)
    label=Label(frame1,text='I have an account',bg="white",fg='black',font=('Telegram UI Light', 9))
    label.place(x=90,y=340)
    
    signin = Button(frame1, width=6,text='sign in',bg="white",fg='#57a1f8',border=0,cursor='hand2',command=sign)
    signin.place(x=200,y=340)
    
    telegram2.mainloop()
      

        
    
load = Image.open("E:\\Telegram-message\\telegram_sign_up_image.jpg")
render = ImageTk.PhotoImage(load)

img = Label(telegram1, image=render,border=0,bg='white')
img.image = render
img.place(x=50, y=50)

#Label(telegram1,image=render,bg ="white").place(x=50,y=50)


frame = Frame(telegram1, width=350,height=350,bg="white")
frame.place(x=480,y=70)

heading=Label(frame, text ='sign in', fg='#57a1f8', bg ='white', font=('Telegram UI Light', 23,'bold'))
heading.place(x=100,y=5)

########################################################

def on_enter(e):
    usr.delete(0, 'end')
    
def on_leave(e):
    name=usr.get()
    if name=='':
        usr.insert(0, 'username')
    
    

usr=Entry(frame, width=25, fg='black', border=0, bg ='white', font=('Telegram UI Light', 11))
usr.place(x=30,y=80)
usr.insert(0,'username')
usr.bind('<FocusIn>', on_enter)
usr.bind('<FocusOut>', on_leave)

Frame(frame, width=295,height=3,bg="black").place(x=25,y=107)

########################################################################

def on_enter(e):
    password1.delete(0, 'end')
    
def on_leave(e):
    name=password1.get()
    if name=='':
        password1.insert(0, 'password')

password1=Entry(frame, width=25, fg='black', border=0, bg ='white', font=('Telegram UI Light', 11))
password1.place(x=30,y=150)
password1.insert(0,'password')
password1.bind('<FocusIn>', on_enter)
password1.bind('<FocusOut>', on_leave)

Frame(frame, width=295,height=3,bg="black").place(x=25,y=177)

################################################################################

Button(frame, width=39,pady=8,text='sign in',bg="#57a1f8",fg='white',border=0,command=signin).place(x=35,y=204)
label=Label(frame,text='Do not have an account?',bg="white",fg='black',font=('Telegram UI Light', 9))
label.place(x=75,y=270)
            

sign_up = Button(frame, width=7,text='sign up',bg="white",fg='#57a1f8',border=0,cursor='hand2',command=signup_command)
sign_up.place(x=215,y=270)

telegram1.mainloop()


'''
## NOTE:-
username:- bhavik
password:- 1234

'''
# Out:
# '\n## NOTE:-\nusername:- bhavik\npassword:- 1234\n\n'
